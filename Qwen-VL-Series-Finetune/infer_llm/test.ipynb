# %%
key='3243ab359a2c4e5f97232d6d9b28318d'

from openai import OpenAI
import openai
client = openai.AzureOpenAI(
    azure_endpoint="https://ai-tencentazureit008ai1082206306322854.cognitiveservices.azure.com/openai/responses?api-version=2025-04-01-preview",
    api_key="3243ab359a2c4e5f97232d6d9b28318d",
    api_version="2025-04-01-preview"
)
# client = OpenAI(
#     base_url="https://ai-tencentazureit008ai1082206306322854.cognitiveservices.azure.com/openai/responses?api-version=2025-04-01-preview",
#     api_key=key,
# )

response = client.responses.create(
    model="GPT-5",
    input=[
        {"role": "system", "content": "As an AI assistant with expertise in severe weather analysis and forecasting, you are equipped to interpret comprehensive figures illustrating various weather variables. Your responsibility as a weather forecaster is to produce a general weather forecast for the future using the current weather condition images provided."},
        {"role": "user", "content": "hello"},
    ]
)

print(response.output_text)
# Out:
# Hi! How can I help with your weather today?
# - Tell me your location (city/region) and time frame (next 24 hours, 3–5 days, etc.), and I’ll give you a forecast.
# - If you have any weather images (radar, satellite, model maps), upload them and I’ll interpret them for a more detailed outlook.
# - Let me know your preferred units (°F/°C, mph/km/h).

# %%
import requests
import json

# 你的 API URL（不要带 /responses?api-version=xxx 的查询参数）
base_url = "https://ai-tencentazureit008ai1082206306322854.cognitiveservices.azure.com/openai/responses?api-version=2025-04-01-preview"
api_key = "3243ab359a2c4e5f97232d6d9b28318d"
headers = {
    "Content-Type": "application/json",
    "api-key": api_key
}

# 请求体
payload = {"model": "GPT-5","input": messages}

# 请求头

# POST 请求
response = requests.post(
    f"{base_url}",
    headers=headers,
    data=json.dumps(payload)
)

# 输出结果
print(response.json())  # 或者 print(response.json()["output_text"]) 如果有这个字段
data = response.json().get("output", [])

# 遍历 output
for block in data:
    if block.get("type") == "message" and "content" in block:
        for c in block["content"]:
            if c.get("type") == "output_text":
                print(c.get("text"))
# Out:
# {'id': 'resp_0bd497ce909e13d4006916a8f28f4c81959fbed5220783115d', 'object': 'response', 'created_at': 1763092722, 'status': 'completed', 'background': False, 'content_filters': None, 'error': None, 'incomplete_details': None, 'instructions': None, 'max_output_tokens': None, 'max_tool_calls': None, 'model': 'GPT-5', 'output': [{'id': 'rs_0bd497ce909e13d4006916a8f32b0081958cb095d49ae36f36', 'type': 'reasoning', 'summary': []}, {'id': 'msg_0bd497ce909e13d4006916a902d7b48195b36d1575e3d18336', 'type': 'message', 'status': 'completed', 'content': [{'type': 'output_text', 'annotations': [], 'logprobs': [], 'text': 'Hi there! I can put together a forecast, including any severe weather risks, if you share:\n\n- Your location (city/region)\n- Time window you care about (today, next 3–5 days, weekend, etc.)\n- Any weather images you have (radar/satellite, model charts, fronts/pressures, 500 mb, CAPE, wind, skew-T)\n\nIf you don’t have images, just give me the location and timeframe and I’ll use
# ...

# %%
import config
list_area = []
for short_area in config.final_stations:
    area=config.stations[short_area].split(",")[0]
    province = config.stations[short_area].split(",")[1][1:]
    list_area.append(f"{area} ({province})")
join_area = ", ".join(list_area)
print(join_area)
# Out:
# Albuquerque (New Mexico), Wakefield (Virginia), Albany (New York), Binghamton (New York), Boston (Massachusetts), Burlington (Vermont), Buffalo (New York), Columbia (South Carolina), Caribou (Maine), Cleveland (Ohio), State College (Pennsylvania), Flagstaff (Arizona), Greer (South Carolina), Portland (Maine), Honolulu (Hawaii), Wilmington (North Carolina), Wilmington (Ohio), Los Angeles (California), Sterling (Virginia), Newport/Morehead (North Carolina), San Francisco Bay Area (California), Spokane (Washington), Mt. Holly (New Jersey), Portland (Oregon), Raleigh/Durham (North Carolina), Charleston (West Virginia), Blacksburg (Virginia), Seattle/Tacoma (Washington), San Diego (California), Great Falls (Montana), Las Vegas (Nevada)

# %%
data[1]['content'][0]['text']
# Out:
# 'Each night, a sleepy unicorn tiptoed across the moonlit meadow, sprinkling quiet stars into the sky so children everywhere would have sweet dreams.'
